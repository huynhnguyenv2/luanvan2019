# %%
import pandas as pd
import numpy as np

data = pd.read_csv('./madrid_2001.csv')
data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-4bf273012fc3> in <module>
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3
#       4 data = pd.read_csv('./madrid_2001.csv')
#       5 data
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import pandas as pd
import numpy as np

data = pd.read_csv('./madrid_2001.csv')
data
# Out:
#                        date    BEN    CO   EBE    MXY  NMHC       NO_2  \
# 0       2001-08-01 01:00:00    NaN  0.37   NaN    NaN   NaN  58.400002
# 1       2001-08-01 01:00:00   1.50  0.34  1.49   4.10  0.07  56.250000
# 2       2001-08-01 01:00:00    NaN  0.28   NaN    NaN   NaN  50.660000
# 3       2001-08-01 01:00:00    NaN  0.47   NaN    NaN   NaN  69.790001
# 4       2001-08-01 01:00:00    NaN  0.39   NaN    NaN   NaN  22.830000
# ...                     ...    ...   ...   ...    ...   ...        ...
# 217867  2001-04-01 00:00:00  10.45  1.81   NaN    NaN   NaN  73.000000
# 217868  2001-04-01 00:00:00   5.20  0.69  4.56    NaN  0.13  71.080002
# 217869  2001-04-01 00:00:00   0.49  1.09   NaN   1.00  0.19  76.279999
# 217870  2001-04-01 00:00:00   5.62  1.01  5.04  11.38   NaN  80.019997
# 217871  2001-04-01 00:00:00   8.09  1.62  6.66  13.04  0.18  76.809998
#
#                NOx   OXY        O_3        PM10   PXY       SO_2   TCH    TOL  \
# ...

# %%
import csv

with open('madrid_2001.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    for row in csv_reader:
        if row[-1] == '28079001'and row[0] ==  :
            print(row)
        else: 
            continue
# Out:
# ['2001-08-01 01:00:00', '', '0.3700000047683716', '', '', '', '58.400001525878906', '87.1500015258789', '', '34.529998779296875', '105.0', '', '6.340000152587891', '', '', '28079001']
# ['2001-08-01 02:00:00', '', '0.41999998688697815', '', '', '', '65.76000213623047', '93.83000183105469', '', '27.93000030517578', '69.75', '', '7.150000095367432', '', '', '28079001']
# ['2001-08-01 03:00:00', '', '0.3199999928474426', '', '', '', '61.09000015258789', '88.08999633789062', '', '32.06999969482422', '56.220001220703125', '', '6.260000228881836', '', '', '28079001']
# ['2001-08-01 04:00:00', '', '0.23000000417232513', '', '', '', '47.02000045776367', '62.93000030517578', '', '42.209999084472656', '50.689998626708984', '', '5.190000057220459', '', '', '28079001']
# ['2001-08-01 05:00:00', '', '0.1899999976158142', '', '', '', '47.16999816894531', '62.630001068115234', '', '48.459999084472656', '49.4900016784668', '', '5.03000020980835', '', '', '28079001']
# ...

# %%
import csv
from datetime import datetime
with open('madrid_2001.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    for row in csv_reader:
        if row[-1] == '28079001':
            print(datetime.strptime(row[0], '%m/%d/%y'))
        else: 
            continue
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-ec1a870e8f41> in <module>
#       5     for row in csv_reader:
#       6         if row[-1] == '28079001':
# ----> 7             print(datetime.strptime(row[0], '%m/%d/%y'))
#       8         else:
#       9             continue
#
# /usr/local/Cellar/python/3.7.4_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/_strptime.py in _strptime_datetime(cls, data_string, format)
#     575     """Return a class cls instance based on the input string and the
#     576     format string."""
# --> 577     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     578     tzname, gmtoff = tt[-2:]
#     579     args = tt[:6] + (fraction,)
#
# /usr/local/Cellar/python/3.7.4_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/_strptime.py in _strptime(data_string, format)
#     357     if not found:
# ...

# %%
import csv
from datetime import datetime
with open('madrid_2001.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    
    for row in csv_reader:
        if row[-1] == '28079001' and datetime.strptime(row[0],'%Y-%m-%d %H:%M:%S').date() == '2001-08-01':
            print(row)
        else: 
            continue
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-03e9d32fd383> in <module>
#       5
#       6     for row in csv_reader:
# ----> 7         if row[-1] == '28079001' and datetime.strptime(row[0],'%Y-%d-%m %H:%M:%S').date() == '2001-08-01':
#       8             print(row)
#       9         else:
#
# /usr/local/Cellar/python/3.7.4_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/_strptime.py in _strptime_datetime(cls, data_string, format)
#     575     """Return a class cls instance based on the input string and the
#     576     format string."""
# --> 577     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     578     tzname, gmtoff = tt[-2:]
#     579     args = tt[:6] + (fraction,)
#
# /usr/local/Cellar/python/3.7.4_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/_strptime.py in _strptime(data_string, format)
# ...

# %%
import csv
from datetime import datetime
with open('madrid_2001.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    
    for row in csv_reader:
        if row[-1] == '28079001' and datetime.strptime(row[0],'%Y-%m-%d %H:%M:%S').date() == '2001-08-01':
            print(row)
        else: 
            continue

# %%
import pandas
from datetime import datetime
df = pandas.read_csv('madrid_2001.csv')
time = datetime.strptime(df.date[0],'%Y-%m-%d %H:%M:%S').date()
time2 = datetime.strptime(df.date[1],'%Y-%m-%d %H:%M:%S').date()
print(time == time2 )
# Out:
# True

# %%
print(df.date())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-8e173c144bbb> in <module>
# ----> 1 print(df.date())
#
# TypeError: 'Series' object is not callable

# %%
print(df[0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-cccbe0f2f7d8> in <module>
# ----> 1 print(df[0])
#
# ...

# %%
print(type(df.date))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>
